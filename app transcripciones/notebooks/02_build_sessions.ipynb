# %% [markdown]
# # 02 Build Sessions
#
# Usa los manifests ya procesados para revisar sesiones y notas estructuradas.

# %%
from cis.config.settings import get_settings
from cis.domain.models import Session
from cis.storage.manifest_store import ManifestStore
from cis.storage.paths import CISPaths

settings = get_settings()
paths = CISPaths(settings)
sessions = ManifestStore(paths.sessions_manifest('sismo'), Session).all()
sessions
