# %% [markdown]
# # 06 Debug And Audit
#
# Revisa contexto permitido, sesiones y figuras sin meter logica critica en el notebook.

# %%
from cis.config.settings import get_settings
from cis.domain.models import Session
from cis.storage.manifest_store import ManifestStore
from cis.storage.paths import CISPaths

paths = CISPaths(get_settings())
ManifestStore(paths.sessions_manifest('sismo'), Session).all()[:5]
