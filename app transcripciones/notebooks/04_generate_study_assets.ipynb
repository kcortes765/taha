# %% [markdown]
# # 04 Generate Study Assets
#
# Genera review semanal y pre-exam desde el backend, sin logica de negocio en el notebook.

# %%
from cis.orchestration.pipeline_weekly import run_weekly_review
from cis.orchestration.pipeline_pre_exam import run_pre_exam

weekly = run_weekly_review('sismo')
pre_exam = run_pre_exam('sismo')
weekly, pre_exam
