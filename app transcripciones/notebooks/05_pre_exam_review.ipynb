# %% [markdown]
# # 05 Pre Exam Review
#
# Inspecciona el archivo consolidado para pre-prueba o examen.

# %%
from cis.config.settings import get_settings
from cis.storage.filesystem import read_text
from cis.storage.paths import CISPaths

paths = CISPaths(get_settings())
read_text(paths.derived_dir('sismo') / 'pre_exam_review.md')[:2000]
