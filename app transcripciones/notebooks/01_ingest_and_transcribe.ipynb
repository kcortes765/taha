# %% [markdown]
# # 01 Ingest And Transcribe
#
# Notebook operativo delgado para correr la ingesta diaria y la transcripcion con Whisper large-v3.

# %%
from cis.orchestration.pipeline_daily import run_daily_pipeline

result = run_daily_pipeline()
result.model_dump()
